# %% [markdown]
# ### 1D Array Operations:
#
# #### Access Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(1)
# - Average Case Time Complexity: O(1)
# - Space Complexity: O(1)
#
# #### Insert Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(n)
# - Average Case Time Complexity: O(1)
# - Space Complexity: O(1)
#
# #### Delete Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(n)
# - Average Case Time Complexity: O(n)
# - Space Complexity: O(1)
#
# #### Update Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(1)
# - Average Case Time Complexity: O(1)
# - Space Complexity: O(1)
#
# #### Traverse Array:
# - Best Case Time Complexity: O(n)
# - Worst Case Time Complexity: O(n)
# - Average Case Time Complexity: O(n)
# - Space Complexity: O(1)
#
# #### Sort Array:
# - Best Case Time Complexity: O(n log n)
# - Worst Case Time Complexity: O(n log n)
# - Average Case Time Complexity: O(n log n)
# - Space Complexity: O(1)
#
# #### Search Array:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(n)
# - Average Case Time Complexity: O(n)
# - Space Complexity: O(1)
#
# ### 2D Array Operations:
#
# #### Access Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(1)
# - Average Case Time Complexity: O(1)
# - Space Complexity: O(1)
#
# #### Insert Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(1)
# - Average Case Time Complexity: O(1)
# - Space Complexity: O(1)
#
# #### Delete Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(n)
# - Average Case Time Complexity: O(n)
# - Space Complexity: O(1)
#
# #### Update Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(1)
# - Average Case Time Complexity: O(1)
# - Space Complexity: O(1)
#
# #### Traverse Array:
# - Best Case Time Complexity: O(n*m)
# - Worst Case Time Complexity: O(n*m)
# - Average Case Time Complexity: O(n*m)
# - Space Complexity: O(1)
#
# #### Sort Array:
# - Best Case Time Complexity: O(n*m log(n*m))
# - Worst Case Time Complexity: O(n*m log(n*m))
# - Average Case Time Complexity: O(n*m log(n*m))
# - Space Complexity: O(1)
#
# #### Search Array:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(n*m)
# - Average Case Time Complexity: O(n*m)
# - Space Complexity: O(1)
#
# ### 3D Array Operations:
#
# #### Access Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(1)
# - Average Case Time Complexity: O(1)
# - Space Complexity: O(1)
#
# #### Insert Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(1)
# - Average Case Time Complexity: O(1)
# - Space Complexity: O(1)
#
# #### Delete Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(n)
# - Average Case Time Complexity: O(n)
# - Space Complexity: O(1)
#
# #### Update Element:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(1)
# - Average Case Time Complexity: O(1)
# - Space Complexity: O(1)
#
# #### Traverse Array:
# - Best Case Time Complexity: O(n*m*p)
# - Worst Case Time Complexity: O(n*m*p)
# - Average Case Time Complexity: O(n*m*p)
# - Space Complexity: O(1)
#
# #### Sort Array:
# - Best Case Time Complexity: O(n*m*p log(n*m*p))
# - Worst Case Time Complexity: O(n*m*p log(n*m*p))
# - Average Case Time Complexity: O(n*m*p log(n*m*p))
# - Space Complexity: O(1)
#
# #### Search Array:
# - Best Case Time Complexity: O(1)
# - Worst Case Time Complexity: O(n*m*p)
# - Average Case Time Complexity: O(n*m*p)
# - Space Complexity: O(1)
